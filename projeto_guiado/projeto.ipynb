# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Analisando dados de vendas dos games
csv_path = 'vgchartz-2024.csv'
dfGames = pd.read_csv(csv_path).drop(columns=['img'])
dfGames.isna().sum()
# Out:
# title               0
# console             0
# genre               0
# publisher           0
# developer          17
# critic_score    57338
# total_sales     45094
# na_sales        51379
# jp_sales        57290
# pal_sales       51192
# other_sales     48888
# release_date     7051
# last_update     46137
# dtype: int64

# %%
# Substituindo valores nulos dos desenvolvedores por 'Unknown'
# dfGames['developer'] = dfGames['developer'].fillna('Unknown')

# Pegando todos os jogos com desenvolvedor 'Unknown'
dfGames.loc[
    dfGames['developer'] == 'Unknown',
]
# Out:
#                        title console         genre  \
# 391                 Monopoly      PC          Misc
# 550                  Destiny    X360          Misc
# 702          Disney Infinity     Wii          Misc
# 787          Disney Infinity    X360          Misc
# 955    Skylanders SWAP Force    X360      Platform
# ...                      ...     ...           ...
# 63170          War on Folvos      PC      Strategy
# 63203          Warrior Chess     And      Strategy
# 63519              Northgard      NS      Strategy
# 63754             Wishmaster      PC  Visual Novel
# 63973     The Mind's Eclipse      PC  Visual Novel
#
#                         publisher developer  critic_score  total_sales  \
# 391            Hasbro Interactive   Unknown           NaN         2.39
# 550                    Activision   Unknown           NaN         1.94
# 702    Disney Interactive Studios   Unknown           NaN         1.66
# ...

# %%
# Quais os 10 jogos mais vendidos?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Quais os 10 jogos mais vendidos?
# ----> 2 dfGames.loc[
#       3     dfGames['total_sales'].sort_values(ascending=False),
#       4     ['name', 'total_sales']
#       5 ]
#
# File ~/Desktop/Programação/Estudo/BackEnd/Python/gc24_analise/pandas_python/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# ...
