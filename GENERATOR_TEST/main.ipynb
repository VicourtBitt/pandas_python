# %%
import pandas as pd

# %%
# O caminho do arquivo armazenado em um CSV
csv_path = ".//data_sample.csv"

# %%
# Lê o arquivo CSV e armazena em um DataFrame
df = pd.read_csv(csv_path, index_col='id')

# Adiciona uma nova coluna ao DataFrame
df['planType'] = df['isFiliated'].apply(
    lambda x: 'Premium' if x == True else 'Free'
) if 'isFiliated' in df.columns else None

# Filtra os dados para remover as linhas com valores nulos
df_na = df.dropna()

# Filtra os dados para encontrar os pagantes que pagaram mais de R$ 800,00
big_payers = df.loc[df['paid'] > 800.00]

# Filtra os dados para encontrar os pagantes que pagaram mais de R$ 1500,00
bigger_payers = df.loc[df['paid'] > 1500.00]

# Filtra os dados para encontrar os pagantes que são filiados
filiatedBigPlayers = big_payers.loc[big_payers['isFiliated'] == True]

# Filtra os dados para encontrar os pagantes que são filiados e são do estado do Amazonas
fbpAM = filiatedBigPlayers.loc[filiatedBigPlayers['state'] == 'AM']

# Podemos fazer queries mais complexas
queryTest = big_payers.loc[
    (big_payers['gender'] == 'Masculino') &
    (big_payers['state'] == 'PE')
]

# Adicionei números invalidos ao pagamento para testar a função isna()
# print(df.loc[df['paid'].isna()])

# Filtrando os dados para ver os pagantes de forma decrescente
# print(df_na.sort_values(by='paid', ascending=False))

# Exibindo a média dos pagamentos
# print(f"O pagamento médio foi de R${df_na['paid'].mean():.2f}")

# Exibindo a quantidade de pagantes por estado
# print(df_na.value_counts('state'))

# Exibindo os pagantes do estado do Rio Grande do Sul por ordem decrescente
print(df_na.query('state == "RS"').sort_values(by='paid', ascending=False))

# Exibindo a quantidade de pagantes por gênero do estado do Rio Grande do Sul 
# print(df_na.query('state == "RS"').value_counts('gender'))
# Out:
#                           name       gender     paid  isFiliated state  \
# id
# 565               Brave Banzai  Não-binário  2875.83       False    RS
# 6            Charming Herschel     Feminino  2452.71        True    RS
# 179             Sweet Hamilton  Não-binário  2389.61        True    RS
# 920               Festive Kare  Não-binário  2351.48        True    RS
# 775          Beautiful Hawking    Masculino  2057.32       False    RS
# 589          Ecstatic Sinoussi    Masculino  1988.79        True    RS
# 289             Nervous Sammet     Feminino  1815.32        True    RS
# 216             Cranky Solomon     Feminino  1676.55       False    RS
# 584           Vibrant Shockley     Feminino  1305.52       False    RS
# 417  Compassionate Nightingale  Não-binário  1291.79        True    RS
# 548             Vibrant Carver     Feminino  1256.00        True    RS
# 887             Fervent Curran  Não-binário  1166.71       False    RS
# 61           Unruffled Bardeen    Masculino  1017.49        True    RS
# 354              Stoic Khayyam    Masculino   998.46       False    RS
# 366               Sharp Wright  Não-binário   968.92       False    RS
# 683                  Nice Cori    Masculino   967.86        True    RS
# 858            Confident Mayer    Masculino   948.51       False    RS
# 88             Unruffled Lewin  Não-binário   793.95       False    RS
# 655            Trusting Jepsen    Masculino   754.19       False    RS
# 744          Vibrant Antonelli  Não-binário   753.50        True    RS
# 149            Angry Albattani    Masculino   620.48        True    RS
# 538               Cool Burnell     Feminino   555.14       False    RS
# 781            Trusting Fermat    Masculino   508.41       False    RS
# 610                Hungry Borg    Masculino   398.60       False    RS
# 859             Naughty Leakey  Não-binário   312.53       False    RS
# 344                 Keen Lewin     Feminino   305.95       False    RS
# 746             Boring Villani  Não-binário   285.47        True    RS
# 205            Ecstatic Liskov    Masculino   242.50       False    RS
# 435         Interesting Bouman  Não-binário   216.69       False    RS
# 978               Hopeful Bohr    Masculino   180.09        True    RS
# 295             Charming Tharp  Não-binário   174.88        True    RS
# 968        Interesting Galileo  Não-binário   169.60       False    RS
# 555                Frosty Cori     Feminino    49.18        True    RS
# 77            Crazy Williamson  Não-binário    41.07        True    RS
# 822              Upbeat Lamarr    Masculino    17.93       False    RS
#
#            date planType
# id
# 565  28-01-2023     Free
# 6    26-03-2021  Premium
# 179  31-08-2022  Premium
# 920  11-03-2021  Premium
# 775  17-06-2021     Free
# 589  29-08-2022  Premium
# 289  03-01-2022  Premium
# 216  09-09-2021     Free
# 584  14-01-2022     Free
# 417  21-06-2020  Premium
# 548  16-12-2021  Premium
# 887  23-12-2022     Free
# 61   24-07-2023  Premium
# 354  20-03-2020     Free
# 366  01-04-2024     Free
# 683  05-11-2020  Premium
# 858  27-03-2020     Free
# 88   07-05-2020     Free
# 655  18-12-2020     Free
# 744  23-08-2022  Premium
# 149  18-10-2024  Premium
# 538  25-11-2022     Free
# 781  07-12-2022     Free
# 610  23-09-2020     Free
# 859  03-10-2024     Free
# 344  01-07-2022     Free
# 746  27-07-2022  Premium
# 205  21-07-2022     Free
# 435  08-09-2022     Free
# 978  20-05-2020  Premium
# 295  08-10-2024  Premium
# 968  25-04-2024     Free
# 555  17-10-2024  Premium
# 77   14-05-2023  Premium
# 822  15-08-2021     Free
