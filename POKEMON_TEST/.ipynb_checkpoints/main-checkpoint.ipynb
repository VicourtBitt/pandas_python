# %%
import pandas as pd

# %%
csv_path = ".//pokemon.csv"

df = pd.read_csv(csv_path, index_col="#")
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
greatAttack = df.loc[df['Attack'] > 150]
greatAttack.count()
# Out:
# Name          18
# Type 1        18
# Type 2        13
# Total         18
# HP            18
# Attack        18
# Defense       18
# Sp. Atk       18
# Sp. Def       18
# Speed         18
# Generation    18
# Legendary     18
# dtype: int64

# %%
lowestSpeed = df.loc[df['Speed'] <= 10]
lowestSpeed.count()
# Out:
# Name          5
# Type 1        5
# Type 2        2
# Total         5
# HP            5
# Attack        5
# Defense       5
# Sp. Atk       5
# Sp. Def       5
# Speed         5
# Generation    5
# Legendary     5
# dtype: int64

# %%
lowestSDef = df.loc[df['Sp. Def'] <= 25]
# lowestSDef = df.query("`Sp. Def` <= 25")
# lowestSDef = (df['Sp. Def'] <= 25).sum()

lowestSDef.count()
# Out:
# 18

# %%
legendaries = df.loc[df['Legendary'] == True]
# legendaries = df.query('Legendary == True')
legendaries
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 144             Articuno       Ice    Flying    580   90      85      100
# 145               Zapdos  Electric    Flying    580   90      90       85
# 146              Moltres      Fire    Flying    580   90     100       90
# 150               Mewtwo   Psychic       NaN    680  106     110       90
# 150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..                   ...       ...       ...    ...  ...     ...      ...
# 719              Diancie      Rock     Fairy    600   50     100      150
# 719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 721            Volcanion      Fire     Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
# df['Ratio'] = (df['Defense'] / df['Attack'])
# biggestRatio = df.sort_values(by='Ratio', ascending=False)
# biggestRatio

# %%
df.sort_values(by=['Defense', 'Attack'], ascending=[False, True])
# Out:
#                     Name    Type 1   Type 2  Total   HP  Attack  Defense  \
# #
# 213              Shuckle       Bug     Rock    505   20      10      230
# 208  SteelixMega Steelix     Steel   Ground    610   75     125      230
# 306    AggronMega Aggron     Steel      NaN    630   70     140      230
# 208              Steelix     Steel   Ground    510   75      85      200
# 377             Regirock      Rock      NaN    580   80     100      200
# ..                   ...       ...      ...    ...  ...     ...      ...
# 238             Smoochum       Ice  Psychic    305   45      30       15
# 172                Pichu  Electric      NaN    205   20      40       15
# 242              Blissey    Normal      NaN    540  255      10       10
# 113              Chansey    Normal      NaN    450  250       5        5
# 440              Happiny    Normal      NaN    220  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary      Ratio
# #
# ...

# %%
fireFlying = df.loc[
    (df['Type 1'] == 'Fire') &
    (df['Type 2'] == 'Flying')
]

fireFlying
# Out:
#                           Name Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 6                    Charizard   Fire  Flying    534   78      84       78
# 6    CharizardMega Charizard Y   Fire  Flying    634   78     104       78
# 146                    Moltres   Fire  Flying    580   90     100       90
# 250                      Ho-oh   Fire  Flying    680  106     130       90
# 662                Fletchinder   Fire  Flying    382   62      73       55
# 663                 Talonflame   Fire  Flying    499   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Ratio
# #
# 6        109       85    100           1      False  0.928571
# 6        159      115    100           1      False  0.750000
# 146      125       85     90           1       True  0.900000
# 250      110      154     90           2       True  0.692308
# 662       56       52     84           6      False  0.753425
# 663       74       69    126           6      False  0.876543

# %%
poisonous = df.loc[
    (df['Type 1'] == 'Poison') |
    (df['Type 2'] == 'Poison')
]

poisonous
# Out:
#                       Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 1                Bulbasaur   Grass  Poison    318   45      49       49
# 2                  Ivysaur   Grass  Poison    405   60      62       63
# 3                 Venusaur   Grass  Poison    525   80      82       83
# 3    VenusaurMega Venusaur   Grass  Poison    625   80     100      123
# 13                  Weedle     Bug  Poison    195   40      35       30
# ..                     ...     ...     ...    ...  ...     ...      ...
# 569               Garbodor  Poison     NaN    474   80      95       82
# 590                Foongus   Grass  Poison    294   69      55       45
# 591              Amoonguss   Grass  Poison    464  114      85       70
# 690                 Skrelp  Poison   Water    320   50      60       60
# 691               Dragalge  Poison  Dragon    494   65      75       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Ratio
# #
# ...

# %%
iceWall = df.loc[
    df['Type 1'] == 'Ice'
]

iceWall.sort_values(by='Defense', ascending=False).iloc[0, 0]
# Out:
# 'Avalugg'

# %%
df.loc[df['Legendary'], 'Type 1'].value_counts()
# Out:
# Psychic     14
# Dragon      12
# Fire         5
# Electric     4
# Water        4
# Rock         4
# Steel        4
# Ground       4
# Grass        3
# Ice          2
# Normal       2
# Ghost        2
# Dark         2
# Flying       2
# Fairy        1
# Name: Type 1, dtype: int64

# %%
df['Generation'].isin([1,2,3]).sum()
# Out:
# 432

# %%
(df.loc[
    (df['Generation'] <= 3) & 
    ((df['Type 1'] == 'Water') | (df['Type 2'] == 'Water'))
]).sort_values(by='Total', ascending=False)
# Out:
#                         Name Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 382      KyogrePrimal Kyogre  Water     NaN    770  100     150       90
# 382                   Kyogre  Water     NaN    670  100     100       90
# 130    GyaradosMega Gyarados  Water    Dark    640   95     155      109
# 260    SwampertMega Swampert  Water  Ground    635  100     150      110
# 9    BlastoiseMega Blastoise  Water     NaN    630   79     103      120
# ..                       ...    ...     ...    ...  ...     ...      ...
# 183                   Marill  Water   Fairy    250   70      20       50
# 270                    Lotad  Water   Grass    220   40      30       30
# 194                   Wooper  Water  Ground    210   55      45       45
# 349                   Feebas  Water     NaN    200   20      15       20
# 129                 Magikarp  Water     NaN    200   20      10       55
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Ratio
# #
# ...

# %%
# Out:
#   Input In [94]
#     df['Type 1'] ||
#                   ^
# SyntaxError: invalid syntax
